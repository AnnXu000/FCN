# %%
import sys
sys.path.append('..')

# %%
import os
from src.models.fcn import fcn

#imagenet weights for vgg16 without classification head
vgg16_weights_path = os.path.expanduser(os.path.join('~', '.keras/models/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'))

#create fcn model
fcn_model = fcn(image_size=(320, 320), upsampling_factor=8, num_classes=21, backbone_weights_path=vgg16_weights_path) 

fcn_model.summary()
# Out:
# Model: "FCN-8s"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              [(None, 320, 320, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 320, 320, 64) 1792        input[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 320, 320, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 160, 160, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 160, 160, 128 73856       block1_pool[0][0]
# ...
